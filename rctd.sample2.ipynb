# %% [markdown]
# # sample2

# %% [markdown]
# We run [RCTD](https://www.nature.com/articles/s41587-021-00830-w) on the sample.

# %% [markdown]
# Here are the libraries we need.

# %%
library(Seurat)
library(dplyr)
library(future)
library(ggplot2)
library(plotly)
library(readr)
library(spacexr)
library(tibble)
# Out:
# Attaching SeuratObject
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout

# %% [markdown]
# We create the output directory for this noteboook.
# Every outputs will save there.

# %%
dir.create("output", showWarnings=F)

# %% [markdown]
# ## Create a reference object

# %% [markdown]
# We load the digital expression matrix and the cell types for the reference.

# %%
ref_counts <- Seurat::Read10X("reference", gene.column=2)

cell_types <-
   readr::read_tsv(file.path("reference", "types.tsv.gz"), col_names=F) %>%
   dplyr::pull(X1) %>%
   setNames(colnames(ref_counts)) %>%
   as.factor()

ref_nUMIs <- colSums(ref_counts)
# Out:
# Rows: 113507 Columns: 1
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): X1
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# We create a RCTD reference object.

# %%
ref <- spacexr::Reference(round(ref_counts), cell_types, ref_nUMIs)
saveRDS(ref, "output/reference.rds")
# Out:
# Warning message in spacexr::Reference(round(ref_counts), cell_types, ref_nUMIs):
# “Reference: number of cells per cell type is 27882, larger than maximum allowable of 10000. Downsampling number of cells to: 10000”

# %% [markdown]
# ## Create a sample object

# %% [markdown]
# We load the digital expression matrix and the spatial information of the sample.

# %%
counts <- Seurat::Read10X("sample2", gene.column=2)

nUMIs <- colSums(counts)

spatial <-
    readr::read_csv("sample2.csv") %>%
    tibble::column_to_rownames("Barcode")

spatial <- spatial[colnames(counts),]

spots <- spacexr::SpatialRNA(spatial, counts, nUMIs)
# Out:
# Rows: 58092 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): Barcode
# dbl (2): x, y
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# We create a RCTD object.

# %%
plan("multicore", workers=12)
rctd <- spacexr::create.RCTD(spots, ref, max_cores=12)
# Out:
# Begin: process_cell_type_info
#
# process_cell_type_info: number of cells in reference: 74862
#
# process_cell_type_info: number of genes in reference: 20310
#             Astrocyte                   CA1                   CA3
#                 10000                 10000                 10000
#         Cajal_Retzius               Choroid                Denate
#                   672                    44                 10000
#     Endothelial_Stalk       Endothelial_Tip           Entorihinal
#                  4233                   676                  4565
#             Ependymal           Interneuron Microglia_Macrophages
#                   715                  6424                  1307
#                 Mural          Neurogenesis        Neuron.Slc17a6
#                  1569                   988                  6337
#       Oligodendrocyte        Polydendrocyte
#                  5050                  2282
# End: process_cell_type_info
#
# create.RCTD: getting regression differentially expressed genes:
#
# get_de_genes: Astrocyte found DE genes: 258
#
# get_de_genes: CA1 found DE genes: 305
#
# get_de_genes: CA3 found DE genes: 382
#
# get_de_genes: Cajal_Retzius found DE genes: 226
#
# get_de_genes: Choroid found DE genes: 219
#
# get_de_genes: Denate found DE genes: 248
#
# get_de_genes: Endothelial_Stalk found DE genes: 376
#
# get_de_genes: Endothelial_Tip found DE genes: 222
#
# get_de_genes: Entorihinal found DE genes: 267
#
# get_de_genes: Ependymal found DE genes: 336
#
# get_de_genes: Interneuron found DE genes: 281
#
# get_de_genes: Microglia_Macrophages found DE genes: 279
#
# get_de_genes: Mural found DE genes: 294
#
# get_de_genes: Neurogenesis found DE genes: 290
#
# get_de_genes: Neuron.Slc17a6 found DE genes: 242
#
# get_de_genes: Oligodendrocyte found DE genes: 278
#
# get_de_genes: Polydendrocyte found DE genes: 223
#
# get_de_genes: total DE genes: 2859
#
# create.RCTD: getting platform effect normalization differentially expressed genes:
#
# get_de_genes: Astrocyte found DE genes: 459
#
# get_de_genes: CA1 found DE genes: 732
#
# get_de_genes: CA3 found DE genes: 771
#
# get_de_genes: Cajal_Retzius found DE genes: 685
#
# get_de_genes: Choroid found DE genes: 473
#
# get_de_genes: Denate found DE genes: 551
#
# get_de_genes: Endothelial_Stalk found DE genes: 669
#
# get_de_genes: Endothelial_Tip found DE genes: 446
#
# get_de_genes: Entorihinal found DE genes: 667
#
# get_de_genes: Ependymal found DE genes: 656
#
# get_de_genes: Interneuron found DE genes: 688
#
# get_de_genes: Microglia_Macrophages found DE genes: 530
#
# get_de_genes: Mural found DE genes: 550
#
# get_de_genes: Neurogenesis found DE genes: 658
#
# get_de_genes: Neuron.Slc17a6 found DE genes: 644
#
# get_de_genes: Oligodendrocyte found DE genes: 440
#
# get_de_genes: Polydendrocyte found DE genes: 489
#
# get_de_genes: total DE genes: 4842

# %% [markdown]
# ## Run RCTD

# %%
rctd <- spacexr::run.RCTD(rctd, doublet_mode="doublet")

saveRDS(rctd, "output/rctd.rds")

readr::write_csv(
   rctd@results$results_df %>% tibble::rownames_to_column("cell"),
   "output/rctd.csv"
)
# Out:
# fitBulk: decomposing bulk
#
# chooseSigma: using initial Q_mat with sigma =  1
#
# Likelihood value: 497456.537291532
#
# Sigma value:  0.86
#
# Likelihood value: 496993.269128722
#
# Sigma value:  0.86
# [1] "gather_results: finished 1000"
# [1] "gather_results: finished 2000"
# [1] "gather_results: finished 3000"
# [1] "gather_results: finished 4000"
# [1] "gather_results: finished 5000"
# [1] "gather_results: finished 6000"
# [1] "gather_results: finished 7000"
# [1] "gather_results: finished 8000"
# [1] "gather_results: finished 9000"

# %% [markdown]
# ## Results

# %% [markdown]
# ### First type

# %%
if ( "first_type" %in% colnames(rctd@results$results_df) )
{
   df <-
      rctd@results$results_df %>%
      tibble::rownames_to_column("cell") %>%
      dplyr::inner_join( spatial %>% tibble::rownames_to_column("cell") )
   
   fig <- plotly::plot_ly(data=df, x=~x, y=~y, color=~first_type)
   
   plotly::save_image(fig, "output/first_type.png")
   plotly::save_image(fig, "output/first_type.pdf")
   
   #fig

   g <- ggplot2::ggplot(df, aes(x=x, y=y, color=first_type)) + geom_point()
   g
}
# Out:
# Joining, by = "cell"
# No trace type specified:
#   Based on info supplied, a 'scatter' trace seems appropriate.
#   Read more about this trace type -> https://plotly.com/r/reference/#scatter
#
# No scatter mode specifed:
#   Setting the mode to markers
#   Read more about this attribute -> https://plotly.com/r/reference/#scatter-mode
#
# Warning message in RColorBrewer::brewer.pal(N, "Set2"):
# “n too large, allowed maximum for palette Set2 is 8
# Returning the palette you asked for with that many colors
# ”
# Warning message in RColorBrewer::brewer.pal(N, "Set2"):
# “n too large, allowed maximum for palette Set2 is 8
# Returning the palette you asked for with that many colors
# ”
# No trace type specified:
#   Based on info supplied, a 'scatter' trace seems appropriate.
#   Read more about this trace type -> https://plotly.com/r/reference/#scatter
#
# No scatter mode specifed:
#   Setting the mode to markers
#   Read more about this attribute -> https://plotly.com/r/reference/#scatter-mode
#
# Warning message in RColorBrewer::brewer.pal(N, "Set2"):
# “n too large, allowed maximum for palette Set2 is 8
# Returning the palette you asked for with that many colors
# ”
# Warning message in RColorBrewer::brewer.pal(N, "Set2"):
# “n too large, allowed maximum for palette Set2 is 8
# Returning the palette you asked for with that many colors
# ”
# plot without title

# %% [markdown]
# ### Second type

# %%
if ( "second_type" %in% colnames(rctd@results$results_df) )
{
   df <-
      rctd@results$results_df %>%
      tibble::rownames_to_column("cell") %>%
      dplyr::inner_join( spatial %>% tibble::rownames_to_column("cell") )
   
   fig <- plotly::plot_ly(data=df, x=~x, y=~y, color=~second_type)
   
   plotly::save_image(fig, "output/second_type.png")
   plotly::save_image(fig, "output/second_type.pdf")
   
   #fig

   g <- ggplot2::ggplot(df, aes(x=x, y=y, color=second_type)) + geom_point()
   g
}
# Out:
# Joining, by = "cell"
# No trace type specified:
#   Based on info supplied, a 'scatter' trace seems appropriate.
#   Read more about this trace type -> https://plotly.com/r/reference/#scatter
#
# No scatter mode specifed:
#   Setting the mode to markers
#   Read more about this attribute -> https://plotly.com/r/reference/#scatter-mode
#
# Warning message in RColorBrewer::brewer.pal(N, "Set2"):
# “n too large, allowed maximum for palette Set2 is 8
# Returning the palette you asked for with that many colors
# ”
# Warning message in RColorBrewer::brewer.pal(N, "Set2"):
# “n too large, allowed maximum for palette Set2 is 8
# Returning the palette you asked for with that many colors
# ”
# No trace type specified:
#   Based on info supplied, a 'scatter' trace seems appropriate.
#   Read more about this trace type -> https://plotly.com/r/reference/#scatter
#
# No scatter mode specifed:
#   Setting the mode to markers
#   Read more about this attribute -> https://plotly.com/r/reference/#scatter-mode
#
# Warning message in RColorBrewer::brewer.pal(N, "Set2"):
# “n too large, allowed maximum for palette Set2 is 8
# Returning the palette you asked for with that many colors
# ”
# Warning message in RColorBrewer::brewer.pal(N, "Set2"):
# “n too large, allowed maximum for palette Set2 is 8
# Returning the palette you asked for with that many colors
# ”
# plot without title

# %% [markdown]
# ## Session info

# %%
sessionInfo()
# Out:
# R version 4.2.1 (2022-06-23)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu Kinetic Kudu (development branch)
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/openblas-pthread/libblas.so.3
# LAPACK: /usr/lib/x86_64-linux-gnu/openblas-pthread/libopenblasp-r0.3.20.so
#
# locale:
#  [1] LC_CTYPE=C.UTF-8    LC_NUMERIC=C        LC_TIME=C
#  [4] LC_COLLATE=C        LC_MONETARY=C       LC_MESSAGES=C
#  [7] LC_PAPER=C          LC_NAME=C           LC_ADDRESS=C
# [10] LC_TELEPHONE=C      LC_MEASUREMENT=C    LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] tibble_3.1.7       spacexr_2.0.0      readr_2.1.2        plotly_4.10.0
# [5] ggplot2_3.3.6      future_1.26.1      dplyr_1.0.9        SeuratObject_4.0.4
# [9] Seurat_4.1.0
#
# loaded via a namespace (and not attached):
#   [1] Rtsne_0.16            colorspace_2.0-3      deldir_1.0-6
#   [4] ellipsis_0.3.2        ggridges_0.5.3        rprojroot_2.0.3
#   [7] IRdisplay_1.1         base64enc_0.1-3       spatstat.data_2.2-0
#  [10] farver_2.1.1          leiden_0.4.2          listenv_0.8.0
#  [13] bit64_4.0.5           ggrepel_0.9.1         fansi_1.0.3
#  [16] codetools_0.2-18      splines_4.2.1         doParallel_1.0.17
#  [19] polyclip_1.10-0       IRkernel_1.3          jsonlite_1.8.0
#  [22] Cairo_1.5-15          ica_1.0-2             cluster_2.1.3
#  [25] png_0.1-7             uwot_0.1.11           shiny_1.7.1
#  [28] sctransform_0.3.3     spatstat.sparse_2.1-1 compiler_4.2.1
#  [31] httr_1.4.3            assertthat_0.2.1      Matrix_1.4-1
#  [34] fastmap_1.1.0         lazyeval_0.2.2        cli_3.3.0
#  [37] later_1.3.0           htmltools_0.5.2       tools_4.2.1
#  [40] igraph_1.3.2          gtable_0.3.0          glue_1.6.2
#  [43] RANN_2.6.1            reshape2_1.4.4        rappdirs_0.3.3
#  [46] Rcpp_1.0.9            scattermore_0.8       vctrs_0.4.1
#  [49] nlme_3.1-158          crosstalk_1.2.0       iterators_1.0.14
#  [52] lmtest_0.9-40         spatstat.random_2.2-0 stringr_1.4.0
#  [55] globals_0.15.1        mime_0.12             miniUI_0.1.1.1
#  [58] lifecycle_1.0.1       irlba_2.3.5           goftest_1.2-3
#  [61] MASS_7.3-57           zoo_1.8-10            scales_1.2.0
#  [64] vroom_1.5.7           spatstat.core_2.4-4   hms_1.1.1
#  [67] promises_1.2.0.1      spatstat.utils_2.3-1  parallel_4.2.1
#  [70] RColorBrewer_1.1-3    reticulate_1.25       pbapply_1.5-0
#  [73] gridExtra_2.3         rpart_4.1.16          stringi_1.7.6
#  [76] foreach_1.5.2         repr_1.1.4            rlang_1.0.3
#  [79] pkgconfig_2.0.3       matrixStats_0.62.0    evaluate_0.15
#  [82] lattice_0.20-45       ROCR_1.0-11           purrr_0.3.4
#  [85] tensor_1.5            labeling_0.4.2        patchwork_1.1.1
#  [88] htmlwidgets_1.5.4     bit_4.0.4             cowplot_1.1.1
#  [91] tidyselect_1.1.2      here_1.0.1            parallelly_1.32.0
#  [94] RcppAnnoy_0.0.19      plyr_1.8.7            magrittr_2.0.3
#  [97] R6_2.5.1              generics_0.1.3        pbdZMQ_0.3-7
# [100] DBI_1.1.3             pillar_1.7.0          withr_2.5.0
# [103] mgcv_1.8-40           fitdistrplus_1.1-8    survival_3.3-1
# [106] abind_1.4-5           future.apply_1.9.0    crayon_1.5.1
# [109] uuid_1.1-0            KernSmooth_2.23-20    utf8_1.2.2
# [112] spatstat.geom_2.4-0   tzdb_0.3.0            grid_4.2.1
# [115] data.table_1.14.2     digest_0.6.29         xtable_1.8-4
# [118] tidyr_1.2.0           httpuv_1.6.5          munsell_0.5.0
# [121] viridisLite_0.4.0     quadprog_1.5-8
